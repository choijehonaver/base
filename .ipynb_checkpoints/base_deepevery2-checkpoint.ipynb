# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import tensorflow as tf

seed = 0
np.random.seed(seed)
# tf.set_random_seed(seed) # error 발생
tf.random.set_seed(seed)

Data_set=np.loadtxt('data/dataset/ThoraricSurgery.csv', delimiter=',')

X=Data_set[:, 0:17]
Y=Data_set[:,17]
print(type(X))

model=Sequential()
model.add(Dense(30, input_dim=17, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=30, batch_size=10)
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# dataset=pd.read_csv('data/dataset/pima-indians-diabetes.csv', delimiter=',',
#               names=['pregnant', 'plasma','pressure','thickness',
#                      'insulin','BMI','pedigree','age','class'])

dataset=np.loadtxt('data/dataset/pima-indians-diabetes.csv', delimiter=',')
X=dataset[:,0:8]
Y=dataset[:,8]
# print(df.corr())
# plt.figure(figsize=(12,12))
# sns.heatmap(df.corr(), linewidth=0.1, vmax=0.5, cmap=plt.cm.gist_heat, linecolor='white', annot=True)
# plt.show()

# grid=sns.FacetGrid(df, col='class')
# grid.map(plt.hist, 'plasma', bins=10)
# plt.show()

seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)
model=Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(X, Y, epochs=200, batch_size=10)
print("\n Accuracy: %.4f" % (model.evaluate(X,Y)[1]))

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils

df=pd.read_csv('data/dataset/iris.csv', names=['sepal_length', 'sepal_width','petal_length', 'petal_width', 'species'])
dataset=df.values # 컬럼 명을 제외한 데이터만 추출해서 넘파이 어레이로 변환
X=dataset[:, 0:4].astype(float)
Y_obj=dataset[:,4]

e=LabelEncoder() # 생성: 객체를 생성해서
e.fit(Y_obj)     # 연결: 카테고리 데이터와 연결하고
Y=e.transform(Y_obj)  # 변환: 숫자로 변환하는 작업을 함.  0,1,2,...
Y_encoded=np_utils.to_categorical(Y) # 0->[1,0,0] 1->[0,1,0] 2->[0,0,1] : 원 핫 인코딩 작업

model=Sequential()
model.add(Dense(16, input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax')) # 활성화 함수는 카테고리 분류에 적합한 소프트맥스를 사용
model.compile(loss='categorical_crossentropy',          # 오차함수는 카테코리컬, 최적화 함수는 아담, 측정은 정도로.
              optimizer='adam',
              metrics=['accuracy'])
model.fit(X, Y_encoded, epochs=50, batch_size=1)
print("\n Accuracy: %.4f" % (model.evaluate(X, Y_encoded)[1]))
# Out:
# Epoch 1/50
# 150/150 [==============================] - 2s 2ms/step - loss: 1.2548 - accuracy: 0.2133
# Epoch 2/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.9473 - accuracy: 0.2267
# Epoch 3/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.7652 - accuracy: 0.4333
# Epoch 4/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.6618 - accuracy: 0.5533
# Epoch 5/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.6004 - accuracy: 0.6133
# Epoch 6/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.5569 - accuracy: 0.6267
# Epoch 7/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.5193 - accuracy: 0.6867
# Epoch 8/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.4885 - accuracy: 0.7133
# Epoch 9/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.7600
# Epoch 10/50
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils

seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

df=pd.read_csv('data/dataset/sonar.csv', header=None)
dataset=df.values
X=dataset[:, 0:60].astype(float)
Y_obj=dataset[:, 60]

e=LabelEncoder()
e.fit(Y_obj)
Y=e.transform(Y_obj)

model=Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['accuracy'])
model.fit(X, Y, epochs=200, batch_size=5) # Failed to convert a NumPy array to a Tensor (Unsupported object type float)
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# Epoch 1/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2468 - accuracy: 0.5096
# Epoch 2/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2269 - accuracy: 0.6971
# Epoch 3/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2153 - accuracy: 0.7115
# Epoch 4/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2048 - accuracy: 0.7115
# Epoch 5/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1969 - accuracy: 0.7260
# Epoch 6/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1871 - accuracy: 0.7692
# Epoch 7/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1768 - accuracy: 0.7788
# Epoch 8/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1715 - accuracy: 0.7837
# Epoch 9/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1620 - accuracy: 0.8125
# Epoch 10/200
# ...

# %%
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy
import tensorflow as tf

seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

df=pd.read_csv('data/dataset/sonar.csv', header=None)
dataset=df.values
X=dataset[:, 0:60].astype(float)
Y_obj=dataset[:, 60]

e=LabelEncoder()
e.fit(Y_obj)
Y=e.transform(Y_obj)

# 학습 세트와 테스트 세트의 구분
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=seed)

model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['accuracy'])
model.fit(X_train, Y_train, epochs=130, batch_size=5)

# 테스트셋에 모델 적용
# print("\n Test Accuracy: %.4f" % (model.evaluate(X_test, Y_test)[1]))
# Out:
# Epoch 1/130
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2459 - accuracy: 0.5310
# Epoch 2/130
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2303 - accuracy: 0.6414
# Epoch 3/130
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2199 - accuracy: 0.6828
# Epoch 4/130
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2102 - accuracy: 0.7724
# Epoch 5/130
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2038 - accuracy: 0.6966
# Epoch 6/130
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1952 - accuracy: 0.7517
# Epoch 7/130
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1882 - accuracy: 0.7724
# Epoch 8/130
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1881 - accuracy: 0.7034
# Epoch 9/130
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1752 - accuracy: 0.8069
# Epoch 10/130
# ...

# %%
from keras.models import load_model
model.save('data/dataset/my_model.h5')
del model

# %%
model=load_model('data/dataset/my_model.h5')
print("\n Test Accuracy: %.4f" % (model.evaluate(X_test, Y_test)[1]))
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1493 - accuracy: 0.7937
#
#  Test Accuracy: 0.7937

# %%
# for 루프문을 돌리므로 tensorflow에서 경고메시지 나옴. 자원 과부하...
# k=10으로 돌리지만, 갈수록 정확도가 향상되는 것이 아니고, 각각은 별개의 결과이므로,
# 10개의 정도 결과 중 최대, 최소, 평균 등의 값으로 감을 잡는 용도이다.
# 여기서는 정확도가 높을 때가 95%, 가장 낮을 때는 71%까지 나왔음.

from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
import numpy
import pandas as pd
import tensorflow as tf

seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

df = pd.read_csv('data/dataset/sonar.csv', header=None)
dataset = df.values
X = dataset[:,0:60].astype(float)
Y_obj = dataset[:,60]

e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)

# 10개의 파일로 쪼갬
n_fold = 10
skf = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)

# 빈 accuracy 배열
accuracy = []

# 모델의 설정, 컴파일, 실행
for train, test in skf.split(X, Y):
    model = Sequential()
    model.add(Dense(24, input_dim=60, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='mean_squared_error',
                  optimizer='adam',
                  metrics=['accuracy'])
    model.fit(X[train], Y[train], epochs=100, batch_size=5)
    k_accuracy = "%.4f" % (model.evaluate(X[test], Y[test])[1])
    accuracy.append(k_accuracy)

# 결과 출력
print("\n %.f fold accuracy:" % n_fold, accuracy)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2426 - accuracy: 0.5455
# Epoch 2/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2260 - accuracy: 0.6578
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2156 - accuracy: 0.7326
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2057 - accuracy: 0.7487
# Epoch 5/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.7219
# Epoch 6/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1843 - accuracy: 0.7540
# Epoch 7/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1730 - accuracy: 0.7861
# Epoch 8/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1631 - accuracy: 0.8075
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1559 - accuracy: 0.8075
# Epoch 10/100
# ...

# %%
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
import numpy
import pandas as pd
import tensorflow as tf
from keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
import os

df_pre=pd.read_csv('data/dataset/wine.csv', header=None)
df=df_pre.sample(frac=0.15)
dataset=df.values
X=dataset[:,0:12]
Y=dataset[:,12]
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# MODEL_DIR='data/dataset/model/'
# if not os.path.exists(MODEL_DIR):
#     os.mkdir(MODEL_DIR)
modelpath='data/dataset/model/{epoch:02d}-{val_loss:.4f}.hdf5'
checkpointer=ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
history=model.fit(X, Y, epochs=2500, batch_size=500, validation_split=0.33, verbose=0, callbacks=[checkpointer])
y_vloss=history.history['val_loss']
y_acc=history.history['accuracy']
x_len=np.arange(len(y_acc))
plt.plot(x_len, y_vloss, 'o', c='red', markersize=3)
plt.plot(x_len, y_acc, 'o', c='blue', markersize=3)
plt.show()
# Out:
# Epoch 1: val_loss improved from inf to 0.57246, saving model to data/dataset/model\01-0.5725.hdf5
#
# Epoch 2: val_loss improved from 0.57246 to 0.41433, saving model to data/dataset/model\02-0.4143.hdf5
#
# Epoch 3: val_loss improved from 0.41433 to 0.32496, saving model to data/dataset/model\03-0.3250.hdf5
#
# Epoch 4: val_loss did not improve from 0.32496
#
# Epoch 5: val_loss did not improve from 0.32496
#
# Epoch 6: val_loss did not improve from 0.32496
#
# Epoch 7: val_loss improved from 0.32496 to 0.30584, saving model to data/dataset/model\07-0.3058.hdf5
#
# Epoch 8: val_loss improved from 0.30584 to 0.29170, saving model to data/dataset/model\08-0.2917.hdf5
#
# Epoch 9: val_loss improved from 0.29170 to 0.28683, saving model to data/dataset/model\09-0.2868.hdf5
#
# Epoch 10: val_loss improved from 0.28683 to 0.28629, saving model to data/dataset/model\10-0.2863.hdf5
#
# Epoch 11: val_loss did not improve from 0.28629
#
# ...

# %%
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
import numpy
import pandas as pd
import tensorflow as tf
from keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
import os

df_pre=pd.read_csv('data/dataset/wine.csv', header=None)
df=df_pre.sample(frac=0.15)
dataset=df.values
X=dataset[:,0:12]
Y=dataset[:,12]
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# MODEL_DIR='data/dataset/model/'
# if not os.path.exists(MODEL_DIR):
#     os.mkdir(MODEL_DIR)
modelpath='data/dataset/model/{epoch:02d}-{val_loss:.4f}.hdf5'
checkpointer=ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback=EarlyStopping(monitor='val_loss', patience=100)
history=model.fit(X, Y, epochs=3500, batch_size=500, validation_split=0.33, verbose=0, callbacks=[early_stopping_callback, checkpointer])
y_vloss=history.history['val_loss']
y_acc=history.history['accuracy']
x_len=np.arange(len(y_acc))
plt.plot(x_len, y_vloss, 'o', c='red', markersize=3)
plt.plot(x_len, y_acc, 'o', c='blue', markersize=3)
plt.show()
# Out:
# Epoch 1: val_loss improved from inf to 0.57246, saving model to data/dataset/model\01-0.5725.hdf5
#
# Epoch 2: val_loss improved from 0.57246 to 0.41433, saving model to data/dataset/model\02-0.4143.hdf5
#
# Epoch 3: val_loss improved from 0.41433 to 0.32496, saving model to data/dataset/model\03-0.3250.hdf5
#
# Epoch 4: val_loss did not improve from 0.32496
#
# Epoch 5: val_loss did not improve from 0.32496
#
# Epoch 6: val_loss did not improve from 0.32496
#
# Epoch 7: val_loss improved from 0.32496 to 0.30584, saving model to data/dataset/model\07-0.3058.hdf5
#
# Epoch 8: val_loss improved from 0.30584 to 0.29170, saving model to data/dataset/model\08-0.2917.hdf5
#
# Epoch 9: val_loss improved from 0.29170 to 0.28683, saving model to data/dataset/model\09-0.2868.hdf5
#
# Epoch 10: val_loss improved from 0.28683 to 0.28629, saving model to data/dataset/model\10-0.2863.hdf5
#
# Epoch 11: val_loss did not improve from 0.28629
#
# ...

# %%
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
import numpy
import pandas as pd
import tensorflow as tf
# from keras.callbacks import ModelCheckpoint, EarlyStopping
# import matplotlib.pyplot as plt
# import os
df=pd.read_csv('data/dataset/housing.csv', delim_whitespace=True, header=None)
dataset=df.values
X=dataset[:,0:13]
Y=dataset[:,13]
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

X_train, X_test, Y_train, Y_test=train_test_split(X, Y, test_size=0.3, random_state=seed)

model=Sequential()
model.add(Dense(30, input_dim=13, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, Y_train, epochs=100, batch_size=10)

Y_prediction=model.predict(X_test).flatten()
for i in range(10):
    label=Y_test[i]
    prediction=Y_prediction[i]
    print("실제가격: {0:.3f}, 예상가격: {1:.3f}".format(label, prediction))
# Out:
# Epoch 1/100
# 36/36 [==============================] - 0s 4ms/step - loss: 8438.0762
# Epoch 2/100
# 36/36 [==============================] - 0s 4ms/step - loss: 732.8657
# Epoch 3/100
# 36/36 [==============================] - 0s 2ms/step - loss: 512.5943
# Epoch 4/100
# 36/36 [==============================] - 0s 2ms/step - loss: 388.6980
# Epoch 5/100
# 36/36 [==============================] - 0s 2ms/step - loss: 256.9742
# Epoch 6/100
# 36/36 [==============================] - 0s 2ms/step - loss: 170.7655
# Epoch 7/100
# 36/36 [==============================] - 0s 2ms/step - loss: 135.6641
# Epoch 8/100
# 36/36 [==============================] - 0s 2ms/step - loss: 123.0019
# Epoch 9/100
# 36/36 [==============================] - 0s 2ms/step - loss: 92.7171
# Epoch 10/100
# 36/36 [==============================] - 0s 2ms/step - loss: 80.1416
# Epoch 11/100
# 36/36 [==============================] - 0s 2ms/step - loss: 72.3035
# Epoch 12/100
# ...
